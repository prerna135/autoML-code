# %%
from scipy.io import arff
import numpy as np
import pandas as pd
import os
from sklearn.pipeline import Pipeline
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.metrics import make_scorer
from collections import defaultdict
from scipy.stats import rankdata
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import pearsonr
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
class surrogate:

    def __init__(self, ntrees=16):
        self.models = {}
        self.ntrees = ntrees

    def get_data(self, data, relevant_params):
        task_ids = data["task_id"].unique()
        data = data[relevant_params + ["task_id"] + ["y"]]
        self.data_dict = defaultdict()
        for task_id in task_ids:
            X_task = data.loc[data["task_id"] == task_id]
            y_task = np.array(X_task["y"], dtype=np.float)
            X_task.drop(["y", "task_id"], 1, inplace=True)
            categorical_names = X_task.select_dtypes(include=['object']).columns
            categorical_ids = [X_task.columns.get_loc(colname) for colname in categorical_names]
            self.data_dict[task_id] = (X_task.as_matrix(), y_task, categorical_ids)
        return task_ids

    def split_data(self, X, y, test_size = 0.15, seed = 42):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)
        return X_train, X_test, y_train, y_test

    def train_model(self, X, y, categoricals, task_id):
        if task_id in self.models:
            return self.models[task_id]
        clf = Pipeline(
            steps=[('encoder', sklearn.preprocessing.OneHotEncoder(
                categorical_features=list(categoricals), handle_unknown='ignore')),
                    ('classifier', RandomForestRegressor(n_estimators=self.ntrees))])
        clf.fit(X, y)
        self.models[task_id] = clf
        return clf

    def average_rank(self, val_task_id):
        X_val, y_val, cat_val = self.data_dict[val_task_id]
        total_ranks = np.zeros(len(X_val))
        for task_id in self.data_dict:
            if task_id == val_task_id:
                continue
            X_train, y_train, cat_train = self.data_dict[task_id]
            clf = self.train_model(X_train, y_train, cat_train, task_id)
            y_val_hat = clf.predict(X_val)
            task_ranks = rankdata(y_val_hat, method='average')
            total_ranks = np.add(total_ranks, task_ranks)
        total_ranks = np.divide(total_ranks, len(X_val))
        return total_ranks

    def custom_scorer(self, y, y_hat):
        return pearsonr(y, y_hat)[0]

    def train_surrogate(self, filename="libsvm_svc.arff", relevant_params=["C", "gamma"]):
        data, meta = arff.loadarff(filename)
        df = pd.DataFrame(data)
        print("Printing sample data")
        print(df[:5])
        print("Data info")
        print(meta)
        task_ids = self.get_data(df, relevant_params)
        for task_id in task_ids:
            X, y, categoricals = self.data_dict[task_id]
            clf = self.train_model(X, y, categoricals, task_id)
            # y_hat = cross_val_predict(clf, X, y, cv=5)
            scores = cross_val_score(clf, X, y, cv=5, scoring=make_scorer(self.custom_scorer))
            # spearman = pearsonr(y, y_hat)
            print("Task %d; Pearson Spearman Correlation: %0.4f (+/- %0.4f)" %(task_id, scores.mean(), scores.std() * 2))
            average_rank = self.average_rank(task_id)
            ar_spearman = pearsonr(y, average_rank)
            print("Task %d; Average Rank: Pearson Spearman Correlation: %f" % (task_id, ar_spearman[0]))

# %%
s = surrogate()
s.train_surrogate()
# Out:
# Printing sample data
#             C     coef0  degree     gamma      kernel max_iter shrinking  \
# 0  162.734738  0.471605     3.0  0.327973     b'poly'    b'-1'   b'True'
# 1    9.845979  0.368980     4.0  0.004604     b'poly'    b'-1'   b'True'
# 2   84.691746  0.002010     NaN  0.000094  b'sigmoid'    b'-1'  b'False'
# 3    0.127243       NaN     NaN  0.025133      b'rbf'    b'-1'  b'False'
# 4  953.723552  0.273139     NaN  0.034387  b'sigmoid'    b'-1'  b'False'
#
#            strategy       tol         y  task_id
# 0           b'mean'  0.001108  0.993116      3.0
# 1         b'median'  0.000089  0.993742      3.0
# 2  b'most_frequent'  0.002602  0.939925      3.0
# 3           b'mean'  0.000268  0.930538      3.0
# 4  b'most_frequent'  0.015420  0.522528      3.0
# Data info
# Dataset: openml-meta-flow-7707
# 	C's type is numeric
# 	coef0's type is numeric
# 	degree's type is numeric
# 	gamma's type is numeric
# 	kernel's type is nominal, range is ('poly', 'sigmoid', 'rbf')
# 	max_iter's type is nominal, range is ('-1',)
# 	shrinking's type is nominal, range is ('True', 'False')
# 	strategy's type is nominal, range is ('mean', 'median', 'most_frequent')
# 	tol's type is numeric
# 	y's type is numeric
# 	task_id's type is numeric
# /Users/prernakashyap/anaconda3/envs/gensim_env/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /Users/prernakashyap/anaconda3/envs/gensim_env/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Task 3; Pearson Spearman Correlation: 0.2920 (+/- 0.0907)
# Task 3; Average Rank: Pearson Spearman Correlation: 0.375926
# Task 6; Pearson Spearman Correlation: 0.3086 (+/- 0.1710)
# Task 6; Average Rank: Pearson Spearman Correlation: 0.333934
# Task 11; Pearson Spearman Correlation: 0.3308 (+/- 0.1372)
# Task 11; Average Rank: Pearson Spearman Correlation: 0.385014
# Task 12; Pearson Spearman Correlation: 0.2949 (+/- 0.2146)
# Task 12; Average Rank: Pearson Spearman Correlation: 0.389577
# Task 14; Pearson Spearman Correlation: 0.3945 (+/- 0.1413)
# Task 14; Average Rank: Pearson Spearman Correlation: 0.502668
# Task 15; Pearson Spearman Correlation: 0.4188 (+/- 0.2680)
# Task 15; Average Rank: Pearson Spearman Correlation: 0.359106
# Task 16; Pearson Spearman Correlation: 0.5879 (+/- 0.1402)
# Task 16; Average Rank: Pearson Spearman Correlation: 0.545469
# Task 18; Pearson Spearman Correlation: 0.4827 (+/- 0.1036)
# Task 18; Average Rank: Pearson Spearman Correlation: 0.345527
# Task 20; Pearson Spearman Correlation: 0.5455 (+/- 0.1736)
# Task 20; Average Rank: Pearson Spearman Correlation: 0.519066
# Task 21; Pearson Spearman Correlation: 0.2201 (+/- 0.1326)
# Task 21; Average Rank: Pearson Spearman Correlation: 0.299006
# Task 22; Pearson Spearman Correlation: 0.6222 (+/- 0.1397)
# Task 22; Average Rank: Pearson Spearman Correlation: 0.628126
# Task 23; Pearson Spearman Correlation: 0.5116 (+/- 0.0465)
# Task 23; Average Rank: Pearson Spearman Correlation: 0.504560
# Task 24; Pearson Spearman Correlation: 0.4402 (+/- 0.0661)
# Task 24; Average Rank: Pearson Spearman Correlation: 0.466365
# Task 28; Pearson Spearman Correlation: 0.5088 (+/- 0.0836)
# Task 28; Average Rank: Pearson Spearman Correlation: 0.602441
# Task 29; Pearson Spearman Correlation: 0.7938 (+/- 0.0905)
# Task 29; Average Rank: Pearson Spearman Correlation: 0.676643
# Task 31; Pearson Spearman Correlation: 0.5180 (+/- 0.0771)
# Task 31; Average Rank: Pearson Spearman Correlation: 0.434893
# Task 32; Pearson Spearman Correlation: 0.2358 (+/- 0.0735)
# Task 32; Average Rank: Pearson Spearman Correlation: 0.418117
# Task 36; Pearson Spearman Correlation: 0.5033 (+/- 0.1788)
# Task 36; Average Rank: Pearson Spearman Correlation: 0.358120
# Task 37; Pearson Spearman Correlation: 0.7097 (+/- 0.0995)
# Task 37; Average Rank: Pearson Spearman Correlation: 0.665235
# Task 41; Pearson Spearman Correlation: 0.5588 (+/- 0.0500)
# Task 41; Average Rank: Pearson Spearman Correlation: 0.641586
# Task 43; Pearson Spearman Correlation: 0.5503 (+/- 0.0220)
# Task 43; Average Rank: Pearson Spearman Correlation: 0.583760
# Task 45; Pearson Spearman Correlation: 0.5222 (+/- 0.2182)
# Task 45; Average Rank: Pearson Spearman Correlation: 0.527154
# Task 49; Pearson Spearman Correlation: 0.3806 (+/- 0.1437)
# Task 49; Average Rank: Pearson Spearman Correlation: 0.281354
# Task 53; Pearson Spearman Correlation: 0.3172 (+/- 0.1310)
# Task 53; Average Rank: Pearson Spearman Correlation: 0.262158
# Task 58; Pearson Spearman Correlation: 0.6761 (+/- 0.1317)
# Task 58; Average Rank: Pearson Spearman Correlation: 0.646962
# Task 219; Pearson Spearman Correlation: 0.1515 (+/- 0.3079)
# Task 219; Average Rank: Pearson Spearman Correlation: 0.241474
# Task 2074; Pearson Spearman Correlation: 0.4317 (+/- 0.1188)
# Task 2074; Average Rank: Pearson Spearman Correlation: 0.386251
# Task 2079; Pearson Spearman Correlation: 0.0699 (+/- 0.0807)
# Task 2079; Average Rank: Pearson Spearman Correlation: 0.234947
# Task 3021; Pearson Spearman Correlation: 0.1127 (+/- 0.2746)
# Task 3021; Average Rank: Pearson Spearman Correlation: 0.157934
# Task 3022; Pearson Spearman Correlation: 0.5804 (+/- 0.1736)
# Task 3022; Average Rank: Pearson Spearman Correlation: 0.148482
# Task 3481; Pearson Spearman Correlation: 0.5088 (+/- 0.1079)
# Task 3481; Average Rank: Pearson Spearman Correlation: 0.478953
# Task 3485; Pearson Spearman Correlation: 0.1717 (+/- 0.1409)
# Task 3485; Average Rank: Pearson Spearman Correlation: 0.290897
# Task 3492; Pearson Spearman Correlation: 0.5260 (+/- 0.1121)
# Task 3492; Average Rank: Pearson Spearman Correlation: 0.192904
# Task 3493; Pearson Spearman Correlation: 0.3502 (+/- 0.1445)
# Task 3493; Average Rank: Pearson Spearman Correlation: -0.279997
# Task 3494; Pearson Spearman Correlation: 0.5325 (+/- 0.2218)
# Task 3494; Average Rank: Pearson Spearman Correlation: 0.553916
# Task 3510; Pearson Spearman Correlation: 0.1230 (+/- 0.2797)
# Task 3510; Average Rank: Pearson Spearman Correlation: 0.249783
# Task 3512; Pearson Spearman Correlation: 0.3966 (+/- 0.1267)
# Task 3512; Average Rank: Pearson Spearman Correlation: 0.515204
# Task 3543; Pearson Spearman Correlation: 0.2664 (+/- 0.2035)
# Task 3543; Average Rank: Pearson Spearman Correlation: 0.365923
# Task 3549; Pearson Spearman Correlation: 0.6218 (+/- 0.1918)
# Task 3549; Average Rank: Pearson Spearman Correlation: 0.581724
# Task 3560; Pearson Spearman Correlation: 0.4938 (+/- 0.1258)
# Task 3560; Average Rank: Pearson Spearman Correlation: 0.437597
# Task 3561; Pearson Spearman Correlation: 0.2847 (+/- 0.1393)
# Task 3561; Average Rank: Pearson Spearman Correlation: 0.301666
# Task 3567; Pearson Spearman Correlation: 0.6908 (+/- 0.0961)
# Task 3567; Average Rank: Pearson Spearman Correlation: 0.605636
# Task 3573; Pearson Spearman Correlation: 0.2979 (+/- 0.4361)
# Task 3573; Average Rank: Pearson Spearman Correlation: -0.228107
# Task 3889; Pearson Spearman Correlation: 0.4223 (+/- 0.2363)
# Task 3889; Average Rank: Pearson Spearman Correlation: 0.395899
# Task 3891; Pearson Spearman Correlation: 0.3910 (+/- 0.1435)
# Task 3891; Average Rank: Pearson Spearman Correlation: 0.436713
# Task 3896; Pearson Spearman Correlation: 0.7295 (+/- 0.1158)
# Task 3896; Average Rank: Pearson Spearman Correlation: 0.657796
# Task 3899; Pearson Spearman Correlation: 0.1800 (+/- 0.2632)
# Task 3899; Average Rank: Pearson Spearman Correlation: 0.237620
# Task 3902; Pearson Spearman Correlation: 0.4456 (+/- 0.1422)
# Task 3902; Average Rank: Pearson Spearman Correlation: 0.464476
# Task 3903; Pearson Spearman Correlation: 0.2823 (+/- 0.6598)
# Task 3903; Average Rank: Pearson Spearman Correlation: 0.087541
# Task 3904; Pearson Spearman Correlation: 0.2459 (+/- 0.1303)
# Task 3904; Average Rank: Pearson Spearman Correlation: 0.181267
# Task 3913; Pearson Spearman Correlation: 0.6240 (+/- 0.1447)
# Task 3913; Average Rank: Pearson Spearman Correlation: 0.382376
# Task 3917; Pearson Spearman Correlation: 0.4433 (+/- 0.1529)
# Task 3917; Average Rank: Pearson Spearman Correlation: 0.398242
# Task 3918; Pearson Spearman Correlation: 0.1581 (+/- 0.2342)
# Task 3918; Average Rank: Pearson Spearman Correlation: -0.025935
# Task 3946; Pearson Spearman Correlation: 0.5390 (+/- 0.2275)
# Task 3946; Average Rank: Pearson Spearman Correlation: -0.199349
# Task 3948; Pearson Spearman Correlation: 0.4527 (+/- 0.1539)
# Task 3948; Average Rank: Pearson Spearman Correlation: -0.160485
# Task 3954; Pearson Spearman Correlation: 0.1449 (+/- 0.2289)
# Task 3954; Average Rank: Pearson Spearman Correlation: 0.242202
# Task 7592; Pearson Spearman Correlation: 0.7008 (+/- 0.0850)
# Task 7592; Average Rank: Pearson Spearman Correlation: 0.593366
# Task 9914; Pearson Spearman Correlation: 0.3052 (+/- 0.4111)
# Task 9914; Average Rank: Pearson Spearman Correlation: 0.012173
# Task 9946; Pearson Spearman Correlation: 0.4167 (+/- 0.1008)
# Task 9946; Average Rank: Pearson Spearman Correlation: 0.469483
# Task 9950; Pearson Spearman Correlation: 0.6358 (+/- 0.0794)
# Task 9950; Average Rank: Pearson Spearman Correlation: 0.686834
# Task 9952; Pearson Spearman Correlation: 0.1393 (+/- 0.2671)
# Task 9952; Average Rank: Pearson Spearman Correlation: -0.172742
# Task 9954; Pearson Spearman Correlation: 0.6242 (+/- 0.1480)
# Task 9954; Average Rank: Pearson Spearman Correlation: 0.512282
# Task 9955; Pearson Spearman Correlation: 0.5280 (+/- 0.1369)
# Task 9955; Average Rank: Pearson Spearman Correlation: 0.205239
# Task 9956; Pearson Spearman Correlation: 0.6073 (+/- 0.1187)
# Task 9956; Average Rank: Pearson Spearman Correlation: 0.475699
# Task 9957; Pearson Spearman Correlation: 0.3069 (+/- 0.0992)
# Task 9957; Average Rank: Pearson Spearman Correlation: 0.382250
# Task 9960; Pearson Spearman Correlation: 0.0481 (+/- 0.1855)
# Task 9960; Average Rank: Pearson Spearman Correlation: 0.142005
# Task 9964; Pearson Spearman Correlation: 0.6112 (+/- 0.1073)
# Task 9964; Average Rank: Pearson Spearman Correlation: 0.657215
# Task 9967; Pearson Spearman Correlation: 0.2665 (+/- 0.1792)
# Task 9967; Average Rank: Pearson Spearman Correlation: 0.349061
# Task 9968; Pearson Spearman Correlation: 0.2593 (+/- 0.3634)
# Task 9968; Average Rank: Pearson Spearman Correlation: 0.388650
# Task 9970; Pearson Spearman Correlation: 0.4899 (+/- 0.0817)
# Task 9970; Average Rank: Pearson Spearman Correlation: -0.150618
# Task 9971; Pearson Spearman Correlation: 0.3721 (+/- 0.2771)
# Task 9971; Average Rank: Pearson Spearman Correlation: 0.023438
# Task 9976; Pearson Spearman Correlation: 0.4092 (+/- 0.2101)
# Task 9976; Average Rank: Pearson Spearman Correlation: 0.439282
# Task 9977; Pearson Spearman Correlation: 0.3380 (+/- 0.0648)
# Task 9977; Average Rank: Pearson Spearman Correlation: 0.358506
# Task 9978; Pearson Spearman Correlation: 0.1030 (+/- 0.1990)
# Task 9978; Average Rank: Pearson Spearman Correlation: 0.029724
# Task 9979; Pearson Spearman Correlation: 0.3464 (+/- 0.2018)
# Task 9979; Average Rank: Pearson Spearman Correlation: 0.331437
# Task 9980; Pearson Spearman Correlation: 0.3706 (+/- 0.4492)
# Task 9980; Average Rank: Pearson Spearman Correlation: 0.012327
# Task 9981; Pearson Spearman Correlation: 0.5596 (+/- 0.1388)
# Task 9981; Average Rank: Pearson Spearman Correlation: 0.558448
# Task 9983; Pearson Spearman Correlation: 0.3285 (+/- 0.1552)
# Task 9983; Average Rank: Pearson Spearman Correlation: -0.289761
# Task 9985; Pearson Spearman Correlation: 0.0793 (+/- 0.0636)
# Task 9985; Average Rank: Pearson Spearman Correlation: -0.055367
# Task 9986; Pearson Spearman Correlation: 0.2334 (+/- 0.2093)
# Task 9986; Average Rank: Pearson Spearman Correlation: 0.312970
# Task 10093; Pearson Spearman Correlation: 0.3435 (+/- 0.2216)
# Task 10093; Average Rank: Pearson Spearman Correlation: 0.391808
# Task 10101; Pearson Spearman Correlation: 0.3752 (+/- 0.0836)
# Task 10101; Average Rank: Pearson Spearman Correlation: 0.051773
# Task 14964; Pearson Spearman Correlation: 0.0221 (+/- 0.1420)
# Task 14964; Average Rank: Pearson Spearman Correlation: -0.088972
# Task 14965; Pearson Spearman Correlation: 0.2218 (+/- 0.3959)
# Task 14965; Average Rank: Pearson Spearman Correlation: 0.190081
# Task 14966; Pearson Spearman Correlation: 0.4612 (+/- 0.0668)
# Task 14966; Average Rank: Pearson Spearman Correlation: 0.439498
# Task 14967; Pearson Spearman Correlation: 0.2776 (+/- 0.1236)
# Task 14967; Average Rank: Pearson Spearman Correlation: 0.346894
# Task 14968; Pearson Spearman Correlation: 0.2122 (+/- 0.1499)
# Task 14968; Average Rank: Pearson Spearman Correlation: 0.367081
# Task 14969; Pearson Spearman Correlation: 0.2227 (+/- 0.1150)
# Task 14969; Average Rank: Pearson Spearman Correlation: 0.321801
# Task 14970; Pearson Spearman Correlation: 0.3413 (+/- 0.1916)
# Task 14970; Average Rank: Pearson Spearman Correlation: 0.395768
# Task 34536; Pearson Spearman Correlation: 0.6953 (+/- 0.0687)
# Task 34536; Average Rank: Pearson Spearman Correlation: 0.582305
# Task 34537; Pearson Spearman Correlation: 0.3462 (+/- 0.0851)
# Task 34537; Average Rank: Pearson Spearman Correlation: 0.417796
# Task 34538; Pearson Spearman Correlation: 0.3454 (+/- 0.1074)
# Task 34538; Average Rank: Pearson Spearman Correlation: 0.318505
# Task 34539; Pearson Spearman Correlation: 0.0680 (+/- 0.2032)
# Task 34539; Average Rank: Pearson Spearman Correlation: -0.113398
# Task 125920; Pearson Spearman Correlation: 0.2982 (+/- 0.2270)
# Task 125920; Average Rank: Pearson Spearman Correlation: 0.295479
# Task 125921; Pearson Spearman Correlation: 0.4599 (+/- 0.2161)
# Task 125921; Average Rank: Pearson Spearman Correlation: 0.385869
# Task 125922; Pearson Spearman Correlation: 0.2146 (+/- 0.1336)
# Task 125922; Average Rank: Pearson Spearman Correlation: 0.327341
# Task 125923; Pearson Spearman Correlation: 0.5960 (+/- 0.1905)
# Task 125923; Average Rank: Pearson Spearman Correlation: 0.572692
# Task 146195; Pearson Spearman Correlation: 0.6687 (+/- 0.1674)
# Task 146195; Average Rank: Pearson Spearman Correlation: 0.379959
# Task 146606; Pearson Spearman Correlation: 0.5896 (+/- 0.0625)
# Task 146606; Average Rank: Pearson Spearman Correlation: 0.276875
# Task 146607; Pearson Spearman Correlation: 0.2095 (+/- 0.1869)
# Task 146607; Average Rank: Pearson Spearman Correlation: 0.103598

# %%
# y = alpha * hyperparameter_1 ^ 2 + beta * hyperparameter_2 ^ 2 + gamma * hyperparameter_1 * hyperparameter_2 + delta
# hyperparameter_1 = gamma
# hyperparameter_2 = complexity (C)
class simplified_surrogate:

    def __init__(self, surrogate):
        self.surrogate = surrogate
        self.models = {}

    def train_model(self):
        for task_id in self.surrogate.data_dict:
            X, y, _ = self.surrogate.data_dict[task_id]
            X = np.append(X, X ** 2, axis = 1)
            model = LinearRegression()
            model.fit(X, y)
            # coeff = model.coef_
            self.models[task_id] = model
            print("Task %d; Pearson Spearman Correlation: %f" % (task_id, pearsonr(y, model.predict(X))[0]))

    def plot_curve(self, task_id):
        X, y, _ = self.surrogate.data_dict[task_id]
        model = self.models[task_id]
        y_hat = model.predict(np.append(X, X ** 2, axis = 1))
        plt.plot(y_hat, c="blue")
        plt.plot(y, c="red")
        plt.axis("equal")

# %%
s_ = simplified_surrogate(s)
s_.train_model()
# Out:
# Task 3; Pearson Spearman Correlation: 0.361622
# Task 6; Pearson Spearman Correlation: 0.209943
# Task 11; Pearson Spearman Correlation: 0.360331
# Task 12; Pearson Spearman Correlation: 0.291551
# Task 14; Pearson Spearman Correlation: 0.331363
# Task 15; Pearson Spearman Correlation: 0.511048
# Task 16; Pearson Spearman Correlation: 0.316331
# Task 18; Pearson Spearman Correlation: 0.225590
# Task 20; Pearson Spearman Correlation: 0.316019
# Task 21; Pearson Spearman Correlation: 0.355955
# Task 22; Pearson Spearman Correlation: 0.516778
# Task 23; Pearson Spearman Correlation: 0.370407
# Task 24; Pearson Spearman Correlation: 0.474911
# Task 28; Pearson Spearman Correlation: 0.524861
# Task 29; Pearson Spearman Correlation: 0.702276
# Task 31; Pearson Spearman Correlation: 0.324804
# Task 32; Pearson Spearman Correlation: 0.279044
# Task 36; Pearson Spearman Correlation: 0.249617
# Task 37; Pearson Spearman Correlation: 0.604665
# Task 41; Pearson Spearman Correlation: 0.466328
# Task 43; Pearson Spearman Correlation: 0.532253
# Task 45; Pearson Spearman Correlation: 0.445707
# Task 49; Pearson Spearman Correlation: 0.214459
# Task 53; Pearson Spearman Correlation: 0.188288
# Task 58; Pearson Spearman Correlation: 0.653764
# Task 219; Pearson Spearman Correlation: 0.195985
# Task 2074; Pearson Spearman Correlation: 0.443384
# Task 2079; Pearson Spearman Correlation: 0.242614
# Task 3021; Pearson Spearman Correlation: 0.092067
# Task 3022; Pearson Spearman Correlation: 0.319674
# Task 3481; Pearson Spearman Correlation: 0.277709
# Task 3485; Pearson Spearman Correlation: 0.198793
# Task 3492; Pearson Spearman Correlation: 0.292321
# Task 3493; Pearson Spearman Correlation: 0.270963
# Task 3494; Pearson Spearman Correlation: 0.555163
# Task 3510; Pearson Spearman Correlation: 0.153637
# Task 3512; Pearson Spearman Correlation: 0.386287
# Task 3543; Pearson Spearman Correlation: 0.318764
# Task 3549; Pearson Spearman Correlation: 0.510097
# Task 3560; Pearson Spearman Correlation: 0.431141
# Task 3561; Pearson Spearman Correlation: 0.232040
# Task 3567; Pearson Spearman Correlation: 0.605743
# Task 3573; Pearson Spearman Correlation: 0.202621
# Task 3889; Pearson Spearman Correlation: 0.289258
# Task 3891; Pearson Spearman Correlation: 0.296589
# Task 3896; Pearson Spearman Correlation: 0.510805
# Task 3899; Pearson Spearman Correlation: 0.244264
# Task 3902; Pearson Spearman Correlation: 0.333228
# Task 3903; Pearson Spearman Correlation: 0.085044
# Task 3904; Pearson Spearman Correlation: 0.304558
# Task 3913; Pearson Spearman Correlation: 0.481857
# Task 3917; Pearson Spearman Correlation: 0.371219
# Task 3918; Pearson Spearman Correlation: 0.180405
# Task 3946; Pearson Spearman Correlation: 0.128512
# Task 3948; Pearson Spearman Correlation: 0.138431
# Task 3954; Pearson Spearman Correlation: 0.198566
# Task 7592; Pearson Spearman Correlation: 0.570965
# Task 9914; Pearson Spearman Correlation: 0.123844
# Task 9946; Pearson Spearman Correlation: 0.498328
# Task 9950; Pearson Spearman Correlation: 0.437218
# Task 9952; Pearson Spearman Correlation: 0.173577
# Task 9954; Pearson Spearman Correlation: 0.425060
# Task 9955; Pearson Spearman Correlation: 0.271873
# Task 9956; Pearson Spearman Correlation: 0.343537
# Task 9957; Pearson Spearman Correlation: 0.306575
# Task 9960; Pearson Spearman Correlation: 0.143722
# Task 9964; Pearson Spearman Correlation: 0.444525
# Task 9967; Pearson Spearman Correlation: 0.374174
# Task 9968; Pearson Spearman Correlation: 0.399123
# Task 9970; Pearson Spearman Correlation: 0.445827
# Task 9971; Pearson Spearman Correlation: 0.192637
# Task 9976; Pearson Spearman Correlation: 0.258326
# Task 9977; Pearson Spearman Correlation: 0.396837
# Task 9978; Pearson Spearman Correlation: 0.026208
# Task 9979; Pearson Spearman Correlation: 0.370779
# Task 9980; Pearson Spearman Correlation: 0.198787
# Task 9981; Pearson Spearman Correlation: 0.336452
# Task 9983; Pearson Spearman Correlation: 0.344665
# Task 9985; Pearson Spearman Correlation: 0.152007
# Task 9986; Pearson Spearman Correlation: 0.248238
# Task 10093; Pearson Spearman Correlation: 0.248451
# Task 10101; Pearson Spearman Correlation: 0.147086
# Task 14964; Pearson Spearman Correlation: 0.234488
# Task 14965; Pearson Spearman Correlation: 0.129539
# Task 14966; Pearson Spearman Correlation: 0.324560
# Task 14967; Pearson Spearman Correlation: 0.265106
# Task 14968; Pearson Spearman Correlation: 0.272568
# Task 14969; Pearson Spearman Correlation: 0.232071
# Task 14970; Pearson Spearman Correlation: 0.346069
# Task 34536; Pearson Spearman Correlation: 0.523117
# Task 34537; Pearson Spearman Correlation: 0.454853
# Task 34538; Pearson Spearman Correlation: 0.192086
# Task 34539; Pearson Spearman Correlation: 0.042438
# Task 125920; Pearson Spearman Correlation: 0.179142
# Task 125921; Pearson Spearman Correlation: 0.222459
# Task 125922; Pearson Spearman Correlation: 0.181442
# Task 125923; Pearson Spearman Correlation: 0.613802
# Task 146195; Pearson Spearman Correlation: 0.469247
# Task 146606; Pearson Spearman Correlation: 0.448471
# Task 146607; Pearson Spearman Correlation: 0.095388
